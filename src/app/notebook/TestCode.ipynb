# %%
print("\"다음은 5GX 프라임 요금제와 비슷한 가격대의 요금제입니다.\\n\\n| 상품명               | 상품설명                                                                                     | VAT포함월정액 | 최소 가입가능 나이 | 최대 가입가능 나이 |\\n|---------------------|---------------------------------------------------------------------------------------------|----------------|-------------------|-------------------|\\n| 5GX 프라임          | 무제한 데이터와 T멤버십 VIP, 구독서비스 할인 등을 제공하는 혜택 요금제                     | 89,000원       | 가입조건 없음     | 가입조건 없음     |\\n| 0 청년 89          | 무제한 데이터와 0청년 특화 혜택을 제공하는 만 34세 이하 개인 고객만 가입 가능한 전용 요금제 | 89,000원       | 0세                | 34세              |\\n| 5GX 프라임(넷플릭스) | 무제한 데이터와 넷플릭스 멤버십을 제공하는 넷플릭스 전용 요금제                           | 89,000원       | 19세              | 가입조건 없음     |\\n| 0 청년 89(넷플릭스) | 무제한 데이터와 0청년 특화 혜택 외 넷플릭스 멤버십을 제공하는 만 19세 이상 34세 이하 개인고객만 가입 가능한 넷플릭스 전용 요금제 | 89,000원       | 19세              | 34세              |\\n\\n위의 요금제들은 모두 89,000원의 월정액으로 제공되며, 다양한 혜택을 포함하고 있습니다.\"".replace("\\n", "\n"))
# Out:
# "다음은 5GX 프라임 요금제와 비슷한 가격대의 요금제입니다.
#
# | 상품명               | 상품설명                                                                                     | VAT포함월정액 | 최소 가입가능 나이 | 최대 가입가능 나이 |
# |---------------------|---------------------------------------------------------------------------------------------|----------------|-------------------|-------------------|
# | 5GX 프라임          | 무제한 데이터와 T멤버십 VIP, 구독서비스 할인 등을 제공하는 혜택 요금제                     | 89,000원       | 가입조건 없음     | 가입조건 없음     |
# | 0 청년 89          | 무제한 데이터와 0청년 특화 혜택을 제공하는 만 34세 이하 개인 고객만 가입 가능한 전용 요금제 | 89,000원       | 0세                | 34세              |
# | 5GX 프라임(넷플릭스) | 무제한 데이터와 넷플릭스 멤버십을 제공하는 넷플릭스 전용 요금제                           | 89,000원       | 19세              | 가입조건 없음     |
# | 0 청년 89(넷플릭스) | 무제한 데이터와 0청년 특화 혜택 외 넷플릭스 멤버십을 제공하는 만 19세 이상 34세 이하 개인고객만 가입 가능한 넷플릭스 전용 요금제 | 89,000원       | 19세              | 34세              |
#
# 위의 요금제들은 모두 89,000원의 월정액으로 제공되며, 다양한 혜택을 포함하고 있습니다."

# %%
import json

# %%
A = "[\n  {\n    \"p\": {\n      \"라인업\": \"0청년 다이렉트 디즈니+ 요금제\",\n      \"상품가입조건\": \"T다이렉트샵(SK텔레콤 공식온라인채널)을 통하여 신규/기변한 만 19세 이상 34세 이하 개인 고객 가입 가능(고객당 1번만 가입 가능)\",\n      \"VAT제외월정액\": 62728,\n      \"VAT포함월정액\": 69000,\n      \"선택약정VAT포함월정액\": 69000,\n      \"상품명\": \"0 청년 다이렉트 69(디즈니+)\",\n      \"상품운영시작일\": \"2025-02-04\",\n      \"과거상품ID\": \"NA00009131\",\n      \"고유ID\": \"PA00002815\",\n      \"상품운영종료일\": \"2262-04-11\",\n      \"상품영문명\": \"0 Youth Direct 69(Disney+)\",\n      \"상품설명\": \"무제한 데이터와 0청년 특화 혜택 외 디즈니 플러스 멤버십을 제공하는 디즈니 플러스 전용 요금제로 SK텔레콤 공식 온라인 채널인 T다이렉트샵에서 만 19세 이상 34세 이하 개인 고객만 가입 가능한 온라인 전용 무약정 요금제\",\n      \"관리정보\": \"고객센터, 대리점, T월드 가입 가능\",\n      \"통신규격\": [\n        \"5G\",\n        \"LTE\"\n      ],\n      \"상품ID\": \"PA00002815\"\n    }\n  },\n  {\n    \"p\": {\n      \"라인업\": \"다이렉트5G 디즈니+ 요금제\",\n      \"상품가입조건\": \"T다이렉트샵(SK텔레콤 공식온라인채널)을 통하여 신규/기변한 만 19세 이상 고객 가입 가능\",\n      \"VAT제외월정액\": 62728,\n      \"VAT포함월정액\": 69000,\n      \"선택약정VAT포함월정액\": 69000,\n      \"상품명\": \"다이렉트 5G 69(디즈니+)\",\n      \"상품운영시작일\": \"2025-02-04\",\n      \"과거상품ID\": \"NA00009128\",\n      \"고유ID\": \"PA00002814\",\n      \"상품운영종료일\": \"2262-04-11\",\n      \"상품영문명\": \"Direct 5G 69(Disney+)\",\n      \"상품설명\": \"무제한 데이터와 디즈니 플러스 멤버십을 제공하는 디즈니 플러스 전용 요금제로 SK텔레콤 공식 온라인 채널인 T다이렉트샵에서만 가입 가능한 온라인 전용 무약정 요금제\",\n      \"관리정보\": \"고객센터, 대리점, T월드 가입 가능\",\n      \"통신규격\": [\n        \"LTE\"\n      ],\n      \"상품ID\": \"PA00002814\"\n    }\n  },\n  {\n    \"p\": {\n      \"라인업\": \"다이렉트5G 스마트기기 요금제\",\n      \"상품가입조건\": \"T다이렉트샵(SK텔레콤 공식온라인채널)을 통하여 신규/기변한 만 19세 이상 고객 가입 가능\",\n      \"VAT제외월정액\": 69091,\n      \"VAT포함월정액\": 76000,\n      \"선택약정VAT포함월정액\": 76000,\n      \"상품명\": \"다이렉트5G 76(스마트기기)\",\n      \"상품운영시작일\": \"2025-01-23\",\n      \"과거상품ID\": \"NA00009101\",\n      \"고유ID\": \"PA00002813\",\n      \"상품운영종료일\": \"2262-04-11\",\n      \"상품영문명\": \"Direct5G 76(smart device)\",\n      \"상품설명\": \"무제한 데이터와 스마트 기기 device 할인 멤버십을 제공하는 스마트 기기 전용 요금제로 SK텔레콤 공식 온라인 채널인 T다이렉트샵에서만 가입 가능한 온라인 전용 무약정 요금제\",\n      \"관리정보\": \"고객센터, 대리점, T월드 가입 가능\",\n      \"통신규격\": [\n        \"LTE\",\n        \"5G\"\n      ],\n      \"상품ID\": \"PA00002813\"\n    }\n  },\n  {\n    \"p\": {\n      \"라인업\": \"0청년 유튜브 프리미엄 요금제\",\n      \"상품가입조건\": \"만 19세 이상~34세 이하 고객 가입 가능(고객당 1번만 가입 가능)\",\n      \"VAT제외월정액\": 99091,\n      \"VAT포함월정액\": 109000,\n      \"선택약정VAT포함월정액\": 81720,\n      \"상품명\": \"0 청년 109(유튜브 프리미엄)\",\n      \"상품운영시작일\": \"2025-01-23\",\n      \"과거상품ID\": \"NA00009123\",\n      \"고유ID\": \"PA00002812\",\n      \"상품운영종료일\": \"2262-04-11\",\n      \"상품설명\": \"무제한 데이터와 0청년 특화 혜택 외 유튜브 프리미엄 멤버십을 제공하는 만 19세 이상 34세 이하 개인고객만 가입 가능한 유튜브 프리미엄 전용 요금제\",\n      \"상품영문명\": \"0 Youth 109(Youtube premium)\",\n      \"통신규격\": [\n        \"5G\",\n        \"LTE\"\n      ],\n      \"관리정보\": \"고객센터, 대리점, T월드 가입 가능\",\n      \"상품ID\": \"PA00002812\"\n    }\n  },\n  {\n    \"p\": {\n      \"라인업\": \"0청년 스마트기기 요금제\",\n      \"상품가입조건\": \"만 19세 이상~34세 이하 고객 가입 가능(고객당 1번만 가입 가능)\",\n      \"VAT제외월정액\": 99091,\n      \"VAT포함월정액\": 109000,\n      \"선택약정VAT포함월정액\": 81720,\n      \"상품명\": \"0 청년 109(스마트기기)\",\n      \"상품운영시작일\": \"2025-01-23\",\n      \"과거상품ID\": \"NA00009102\",\n      \"고유ID\": \"PA00002811\",\n      \"상품운영종료일\": \"2262-04-11\",\n      \"상품영문명\": \"0 Youth 109(Smart device)\",\n      \"상품설명\": \"무제한 데이터와 0청년 특화 혜택 외 스마트 기기 device 할인을 제공하는 만 19세 이상 34세 이하 개인고객만 가입 가능한 스마트 기기 전용 요금제\",\n      \"관리정보\": \"고객센터, 대리점, T월드 가입 가능\",\n      \"통신규격\": [\n        \"5G\",\n        \"LTE\"\n      ],\n      \"상품ID\": \"PA00002811\"\n    }\n  },\n  {\n    \"p\": {\n      \"라인업\": \"5GX플랜 스마트기기 요금제\",\n      \"상품가입조건\": \"19세 이상 성인, 고객 명의당 1개만 가입 가능\",\n      \"VAT제외월정액\": 99091,\n      \"VAT포함월정액\": 109000,\n      \"선택약정VAT포함월정액\": 81720,\n      \"상품명\": \"5GX 프리미엄(스마트기기)\",\n      \"상품운영시작일\": \"2025-01-23\",\n      \"과거상품ID\": \"NA00009100\",\n      \"고유ID\": \"PA00002810\",\n      \"상품운영종료일\": \"2262-04-11\",\n      \"상품영문명\": \"5GX Premium (Smart Device)\",\n      \"상품설명\": \"무제한 데이터와 스마트 기기 device 할인 멤버십을 제공하는 스마트 기기 전용 요금제\",\n      \"관리정보\": \"고객센터, 대리점, T월드 가입 가능\",\n      \"통신규격\": [\n        \"5G\"\n      ],\n      \"상품ID\": \"PA00002810\"\n    }\n  },\n  {\n    \"p\": {\n      \"라인업\": \"5GX플랜 디즈니+ 요금제\",\n      \"상품가입조건\": \"19세 이상 성인, 고객 명의당 1개만 가입 가능\",\n      \"VAT제외월정액\": 99091,\n      \"VAT포함월정액\": 109000,\n      \"선택약정VAT포함월정액\": 81720,\n      \"상품명\": \"5GX 프리미엄(디즈니+)\",\n      \"상품운영시작일\": \"2025-02-04\",\n      \"과거상품ID\": \"NA00009125\",\n      \"고유ID\": \"PA00002809\",\n      \"상품운영종료일\": \"2262-04-11\",\n      \"상품영문명\": \"5GX Premium(Disney+)\",\n      \"상품설명\": \"무제한 데이터와 디즈니 플러스 멤버십을 제공하는 디즈니 플러스 전용 요금제\",\n      \"관리정보\": \"고객센터, 대리점, T월드 가입 가능\",\n      \"통신규격\": [\n        \"LTE\",\n        \"5G\"\n      ],\n      \"상품ID\": \"PA00002809\"\n    }\n  },\n  {\n    \"p\": {\n      \"라인업\": \"5GX플랜 유튜브 프리미엄 요금제\",\n      \"상품가입조건\": \"19세 이상 성인, 고객 명의당 1개만 가입 가능\",\n      \"VAT제외월정액\": 99091,\n      \"VAT포함월정액\": 109000,\n      \"선택약정VAT포함월정액\": 81720,\n      \"상품명\": \"5GX 프리미엄(유튜브 프리미엄)\",\n      \"상품운영시작일\": \"2025-01-23\",\n      \"과거상품ID\": \"NA00009121\",\n      \"고유ID\": \"PA00002808\",\n      \"상품운영종료일\": \"2262-04-11\",\n      \"상품설명\": \"무제한 데이터와 유튜브 프리미엄멤버십을 제공하는 유튜브 혜택 특화 전용 요금제\",\n      \"상품영문명\": \"5GX Premium(Youtube Premium)\",\n      \"통신규격\": [\n        \"LTE\",\n        \"5G\"\n      ],\n      \"관리정보\": \"고객센터, 대리점, T월드 가입 가능\",\n      \"상품ID\": \"PA00002808\"\n    }\n  },\n  {\n    \"p\": {\n      \"라인업\": \"0청년 디즈니+ 요금제\",\n      \"상품가입조건\": \"만 19세 이상~34세 이하 고객 가입 가능(고객당 1번만 가입 가능)\",\n      \"VAT제외월정액\": 99091,\n      \"VAT포함월정액\": 109000,\n      \"선택약정VAT포함월정액\": 81720,\n      \"상품명\": \"0 청년 109(디즈니+)\",\n      \"상품운영시작일\": \"2025-02-04\",\n      \"과거상품ID\": \"NA00009129\",\n      \"고유ID\": \"PA00002807\",\n      \"상품운영종료일\": \"2262-04-11\",\n      \"상품영문명\": \"0 Youth 109(Disney+)\",\n      \"상품설명\": \"무제한 데이터와 0청년 특화 혜택 외 디즈니 플러스 멤버십을 제공하는 만 19세 이상 34세 이하 개인고객만 가입 가능한 디즈니 플러스 전용 요금제\",\n      \"통신규격\": [],\n      \"관리정보\": \"고객센터, 대리점, T월드 가입 가능\",\n      \"상품ID\": \"PA00002807\"\n    }\n  },\n  {\n    \"p\": {\n      \"라인업\": \"다이렉트5G 디즈니+ 요금제\",\n      \"상품가입조건\": \"T다이렉트샵(SK텔레콤 공식온라인채널)을 통하여 신규/기변한 만 19세 이상 고객 가입 가능\",\n      \"VAT제외월정액\": 69091,\n      \"VAT포함월정액\": 76000,\n      \"선택약정VAT포함월정액\": 76000,\n      \"상품명\": \"다이렉트5G 76(디즈니+)\",\n      \"상품운영시작일\": \"2025-02-04\",\n      \"과거상품ID\": \"NA00009127\",\n      \"고유ID\": \"PA00002806\",\n      \"상품운영종료일\": \"2042-12-31\",\n      \"상품영문명\": \"Direct5G 76(Disney+)\",\n      \"상품설명\": \"무제한 데이터와 디즈니 플러스 멤버십을 제공하는 디즈니 플러스 전용 요금제로 SK텔레콤 공식 온라인 채널인 T다이렉트샵에서만 가입 가능한 온라인 전용 무약정 요금제\",\n      \"관리정보\": \"고객센터, 대리점, T월드 가입 가능\",\n      \"통신규격\": [\n        \"5G\"\n      ],\n      \"상품ID\": \"PA00002806\"\n    }\n  }\n]"

# %%
len(json.loads(A))
# Out:
# 10

# %%
from langchain_openai import ChatOpenAI
from langchain_ollama.chat_models import ChatOllama
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler
from langchain.schema import SystemMessage
from langchain_neo4j import Neo4jGraph, GraphCypherQAChain

# %%
from langchain_core.messages import (
    AIMessage,
    HumanMessage,
    SystemMessage,
    FunctionMessage,
)

# %%
from langchain.prompts import PromptTemplate

# %%
from langchain.tools import tool

# %%
@tool(parse_docstring=True)
def get_service_info(svc_mgmt_num: str):
    """
    Retrieves the customer's basic information, including mobile number (svcNum), subscription date (svcScrbDtm), birth date (ssnBirthDt), gender (ssnSexCd, where 1 = male, 2 = female), and subscribing product details such as product ID (feeProdId), product name (feeProdNm), subscription change date (feeProdChgDt), and device model (EqpMdlNm). The customer's age is calculated from the birth date.

    Args:
        svc_mgmt_num (str): Customer's ID number(ex: '7022044239')

    Returns:
        dict: Retrived customer information
    """
    # 실제 API 호출 대신 데모 데이터를 반환
    # 실제 구현에서는 API를 호출하여 데이터를 가져와야 함
    return {
        "svcMgmtNum": "7022044239",
        "svcNum": "01094793421",
        "svcCd": "C",
        "svcStCd": "AC",
        "svcStChgCd": "I1",
        "svcChgRsnCd": "02",
        "svcTypCd": "01",
        "svcScrbDtm": "20231218",
        "scrbReqRsnCd": "02",
        "wlfDcCd": "",
        "estationAgreeYn": "N",
        "feeProdId": "NA00007790",
        "feeProdNm": "5GX 프라임",
        "feeProdChgDt": "20230104",
        "eqpMdlCd": "A3UU",
        "eqpMdlNm": "SM-S901NW",
        "eqpSerNum": "0065549",
        "eqpUsgCd": "W",
        "eqpMthdCd": "F",
        "eqpMktgDt": "20220210",
        "nwMthdCd": "13",
        "custNum": "9252302408",
        "custNm": "익명1",
        "ctzCorpBizNum": "8209292000000",
        "ssnBirthDt": "950929",
        "ssnSexCd": "2",
        "custTypCd": "01",
        "custDtlTypCd": "N0",
        "acntNum": "6425211166",
        "acntTypCd": "01",
        "payMthdCd": "01",
    }


@tool(parse_docstring=True)
def get_subscribed_products(svc_mgmt_num: str = None):
    """
    Retrieves the full list of products the customer is subscribed to, including mobile plans, bundled products, and additional services.

    Args:
        svc_mgmt_num (str): Customer's ID number(ex: '7022044239')

    Returns:
        list: Customer's subscribed products list and details.
    """
    # 실제 API 호출 대신 데모 데이터를 반환
    # 실제 구현에서는 API를 호출하여 데이터를 가져와야 함
    return [
        {
            "svcMgmtNum": "7022044239",
            "scrbProdList": [
                {
                    "prodId": "NA00007790",
                    "prodNm": "5GX 프라임",
                    "svcProdCd": "1",
                    "scrbDt": "20240101",
                },
                {
                    "prodId": "NH00000157",
                    "prodNm": "요즘가족결합",
                    "svcProdCd": "2",
                    "scrbDt": "20240101",
                },
                {
                    "prodId": "NA00000262",
                    "prodNm": "소리샘",
                    "svcProdCd": "3",
                    "scrbDt": "20240101",
                },
            ],
        }
    ]

# %%
CYPHER_GENERATION_TEMPLATE = """Task:Generate Cypher statement to query a graph database.
Instructions:
Use only the provided relationship types and properties in the schema.
Do not use any other relationship types or properties that are not provided.
Limit the number of results to 10.

Schema:
{schema}

Domain mapping and other rules:
- For numeric fields, treat the term 무제한 (unlimited) as the value 999999.
- For age-related queries, check whether the given age is within the range defined by 최소나이 (minimum age) and 최대나이 (maximum age).
- For questions about cheap or expensive plans, sort by the value of VAT포함월정액 (VAT included monthly price).
- Focus primarily on the 마케팅키워드 (marketing keywords) nodes and 상품설명 (product description) fields when finding keywords.
- To handle list type properties, use following style cypher: ANY(item IN node.list_property WHERE item CONTAINS "keyword")
- For search keywords, prefer single nouns without spaces. For example, use "넷플릭스" instead of "넷플릭스 할인".
- For questions about available plans, also retrieve whether the user is eligible to subscribe by checking the 상품가입조건 (productsubscriptioncondition).

For querying list properties, do not use the CONTAINS operator directly on the array itself.
Instead, use one of the following methods depending on the query intent:
- To check for exact inclusion of a value: "value" IN node.array_property
- To check if any element partially matches a condition (e.g., substring): ANY(item IN node.array_property WHERE item CONTAINS "value")
- To check if all elements satisfy a condition: ALL(item IN node.array_property WHERE item CONTAINS "value")

Example:
- "18세 미만만 가입할 수 있는 요금제 알려줘" -> "MATCH (p:요금제)-[:최대가입가능나이]->(maxAge:최대나이) WHERE maxAge.값 < 18 RETURN p, maxAge"
Note: Do not include any explanations or apologies in your responses.
Do not respond to any questions that might ask anything else than for you to construct a Cypher statement.
Do not include any text except the generated Cypher statement.

The question is:
{question}"""

CYPHER_GENERATION_PROMPT = PromptTemplate(
    input_variables=["schema", "question"], template=CYPHER_GENERATION_TEMPLATE
)

CYPHER_QA_TEMPLATE = """You are a product specialist in SK Telecom helps to form nice and human understandable answers in Korean.
The Information part contains the provided information that you must use to construct an answer.
The provided information is authoritative, you must never doubt it or try to use your internal knowledge to correct it.
You should write your answer based on the 상품명 (product name), 상품설명 (product description), and VAT포함월정액 (monthlyprice) fields, and you can utilize additional fields depending on the question.
Make the answer sound as a response to the question. Do not mention that you based the result on the given information.
Here is an example:

Question: 데이터 무제한 요금제 하나만 알려줘
Context:'상품설명': '무제한 데이터와 0청년 특화 혜택 외 디즈니 플러스 멤버십을 제공하는 디즈니 플러스 전용 요금제로 SK텔레콤 공식 온라인 채널인 T다이렉트샵에서 만 19세 이상 34세 이하 개인 고객만 가입 가능한 온라인 전용 무약정 요금제', '라인업': '0청년 다이렉트 디즈니+ 요금제', '상품명': '0 청년 다이렉트 69(디즈니+)', 'VAT포함월정액': 69000
Helpful Answer: 데이터 무제한 요금제에는 0 청년 다이렉트 69(디즈니+)가 있고, 해당 요금제의 월정액 요금은 69,000원입니다. 해당 요금제는 무제한 데이터 외에 0청년 특화 혜택과 디즈니 플러스 멤버십을 제공하며, 만 19세 이상 34세 이하 개인 고객만 가입이 가능한 온라인 전용 무약정 요금제입니다.

Follow this example when generating answers.
If the provided information is empty, say that you don't know the answer.
Information:
{context}

Question: {question}
Helpful Answer:"""

CYPHER_QA_PROMPT = PromptTemplate(
    input_variables=["context", "question"], template=CYPHER_QA_TEMPLATE
)

@tool(parse_docstring=True)
def prod_meta_search(query: str):
    """
    Provides detailed search results for SKTelecom's mobile plans, subscription conditions, additional services, roaming options, and benefitial offers. 
    Takes a user query, generates a Cypher query, and returns the result from the graph database in text format.

    Args:
        query (str): User's query

    Returns:
        dict: Cypher query and search results in text format
    """
    try:
        graph = Neo4jGraph(
            url="bolt://neo4j-gds-apoc-n10s:7687",  #"bolt://localhost:7687",
            username="neo4j",
            password="neo4jpassword",
            # enhanced_schema=True,
            sanitize=True,  # 연결 검증
        )

        # LangChain 초기화
        chain = GraphCypherQAChain.from_llm(
            ChatOpenAI(
                model="gpt-4o-mini",
                openai_api_key="e97ee307-a791-4e06-ade1-df4b9d032eed",
                openai_api_base="https://aihub-api.sktelecom.com/aihub/v2/sandbox",
                streaming=True,
                temperature=0,
            ), 
            cypher_prompt=CYPHER_GENERATION_PROMPT,
            qa_prompt=CYPHER_QA_PROMPT,
            graph=graph, 
            verbose=True,
            allow_dangerous_requests=True,
            exclude_types=["DB타입", "카테고리"],
            return_intermediate_steps=True,
            return_direct=True,
            # validate_cypher=True, 
        )

        # 질문 출력
        print("Query:", query)

        # 쿼리 실행
        chain_result = chain.invoke({"query": query})
        # print(f"Intermediate steps: {result['intermediate_steps']}")
        print(f"Final answer: {chain_result['result']}")

        # Cypher 쿼리와 결과 추출
        cypher = chain_result["intermediate_steps"][0]["query"]
        result_json = json.dumps(chain_result["result"], ensure_ascii=False, indent=2)
        return cypher, result_json

        
    except Exception as e:
        import traceback
        traceback.print_exc()  # 서버 로그에 스택 트레이스 출력
        raise HTTPException(
            status_code=500,
            detail=f"Internal server error: {str(e)}"
        )

# %%
def call_pe_tool_v2(
    messages: list,
    system_message: str,
    tools: list = None,
    model_idx: int = 124252,  # 124730(4.1)
    seed: int = 0,
    tool_choice: str = "auto",
    response_format: str = None,
):
    """
    Call the PE Tool V2 API for chat completions using LangChain's invoke method

    Args:
        messages: Conversation messages
        tools: List of available tools
        model_idx: Model identifier
        seed: Random seed
        tool_choice: Tool selection mode
        response_format: Desired response format

    Returns:
        dict: API response

    Raises:
        ValueError: If API call fails or returns invalid response
    """
    # Process system message same way as in call_pe_tool_v2
    if system_message:
        if len(messages) > 0 and messages[0].type.title().lower() == "system":
            messages[0].content = system_message
        else:
            messages.insert(0, SystemMessage(content=system_message))
    # Serialize messages
    serialized_messages = [message_to_dict(msg) for msg in messages]
    # Prepare model kwargs and options for invoke
    model_kwargs = {}
    invoke_kwargs = {}
    # Handle tools and tool_choice
    if tools:
        model_kwargs["tools"] = tools
        invoke_kwargs["tool_choice"] = tool_choice
    # Handle response_format
    if response_format:
        invoke_kwargs["response_format"] = response_format

    try:
        print("serialized_messages>>>>", serialized_messages)
        # Initialize LangChain OpenAI client
        llm = ChatOpenAI(
            base_url="https://aide.dev.apollo-lunar.com/pe-proxy/api/v1/compatible/openai/stream",
            streaming=True,
            callbacks=[StreamingStdOutCallbackHandler()],
            temperature=0,
            model=str(model_idx),
            api_key="None",
            seed=seed,
            # **model_kwargs,
        )
        # Call API via LangChain with additional parameters
        if tools:
            print("llm_with_tools>>>>")
            print(tools)
            llm_with_tools = llm.bind_tools(tools)
            response = llm_with_tools.invoke(serialized_messages, **invoke_kwargs)
        else:
            response = llm.invoke(serialized_messages, **invoke_kwargs)
        return response
    except Exception as e:
        print("call_pe_tool_v2 error>>>>", e)
        raise ValueError(f"API 오류: {str(e)}")

# %%
system_msg = """
User query: 유튜브 프리미엄 할인되는 요금제 중에 33세가 가입 가능한 가장 싼 요금제 알려줘
Plan: [{'step': 1, 'tool': 'prod_meta_search', 'reason': 'To find the cheapest plan with YouTube Premium discount for a 33-year-old'}]
Results from past steps: None, it's the first step.
Task of current step: To find the cheapest plan with YouTube Premium discount for a 33-year-old
"""

# %%
user_msg = "Select the most appropriate tool for the user's query at the current stage."

# %%
tools = [prod_meta_search, get_service_info, get_subscribed_products]

# %%
def message_to_dict(message):
    """Convert various message formats to a standardized dictionary format."""
    if hasattr(message, "to_dict"):
        return message.to_dict()
    elif isinstance(message, dict):
        result = message.copy()
        if "content" not in result:
            result["content"] = ""
        return result
    if message.type.title().lower() == "human":
        role = "user"
        return {"role": role, "content": message.content}
    elif message.type.title().lower() == "ai":
        role = "assistant"
        return {"role": role, "content": message.content}
    elif message.type.title().lower() == "system":
        role = "system"
        return {"role": role, "content": message.content}
    elif message.type.title().lower() == "function" or message.type.title().lower() == "tool":
        role = "assistant"
        return {"role": role, "name": message.name, "content": message.content}
    else:
        print("message.type.title()>>>>", message.type.title())
        raise ValueError("message.type.title()>>>>", message.type.title())

# %%
resp = call_pe_tool_v2(
    system_message=system_msg,
    messages=[
        HumanMessage(
            content=user_msg
        )
    ],
    tools=tools,
)
# Out:
# serialized_messages>>>> [{'role': 'system', 'content': "\nUser query: 유튜브 프리미엄 할인되는 요금제 중에 33세가 가입 가능한 가장 싼 요금제 알려줘\nPlan: [{'step': 1, 'tool': 'prod_meta_search', 'reason': 'To find the cheapest plan with YouTube Premium discount for a 33-year-old'}]\nResults from past steps: None, it's the first step.\nTask of current step: To find the cheapest plan with YouTube Premium discount for a 33-year-old\n"}, {'role': 'user', 'content': "Select the most appropriate tool for the user's query at the current stage."}]
# llm_with_tools>>>>
# ...

# %%
resp
# Out:
# AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_3APUBOaI5vUpGRrZZMJxcmyh', 'function': {'arguments': '{"query":"33세가 가입 가능한 유튜브 프리미엄 할인 요금제 중 가장 저렴한 요금제"}', 'name': 'prod_meta_search'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'GIP@azure/openai/gpt-4o-2024-11-20/provisioned', 'system_fingerprint': 'fp_ee1d74bde0'}, id='run--c430c912-922e-4d0b-8a63-334945543226-0', tool_calls=[{'name': 'prod_meta_search', 'args': {'query': '33세가 가입 가능한 유튜브 프리미엄 할인 요금제 중 가장 저렴한 요금제'}, 'id': 'call_3APUBOaI5vUpGRrZZMJxcmyh', 'type': 'tool_call'}], usage_metadata={'input_tokens': 400, 'output_tokens': 39, 'total_tokens': 439, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
model_kwargs = {"tools": tools}

# %%
llm = ChatOpenAI(
    base_url="https://aide.dev.apollo-lunar.com/pe-proxy/api/v1/compatible/openai/stream",
    streaming=True,
    callbacks=[StreamingStdOutCallbackHandler()],
    temperature=0,
    model=str(124252),
    api_key="None",
    seed=0,
    **model_kwargs
)
# Out:
# /usr/local/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3610: UserWarning: WARNING! tools is not default parameter.
#                 tools was transferred to model_kwargs.
#                 Please confirm that tools is what you intended.
#   if await self.run_code(code, result, async_=asy):

# %%
llm_with_tools = llm.bind_tools(tools)

# %%
query = "유튜브 프리미엄 할인되는 요금제 중에 33세가 가입 가능한 가장 싼 요금제 알려줘"

llm_with_tools.invoke(query)
# Out:
# AIMessage(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_f7r3x5JpkXdViKT1diT2M1pI', 'function': {'arguments': '{"query":"유튜브 프리미엄 할인 요금제 중 33세 가입 가능한 가장 저렴한 요금제"}', 'name': 'prod_meta_search'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'GIP@azure/openai/gpt-4o-2024-11-20/provisioned', 'system_fingerprint': 'fp_ee1d74bde0'}, id='run--d0ab2213-8147-4229-b4a0-748ed0016e20-0', tool_calls=[{'name': 'prod_meta_search', 'args': {'query': '유튜브 프리미엄 할인 요금제 중 33세 가입 가능한 가장 저렴한 요금제'}, 'id': 'call_f7r3x5JpkXdViKT1diT2M1pI', 'type': 'tool_call'}], usage_metadata={'input_tokens': 309, 'output_tokens': 39, 'total_tokens': 348, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
llm.invoke(query)
# Out:
# ---------------------------------------------------------------------------
# PydanticSerializationError                Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 llm.invoke(query)
#
# File /usr/local/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:371, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     359 @override
#     360 def invoke(
#     361     self,
#    (...)    366     **kwargs: Any,
#     367 ) -> BaseMessage:
#     368     config = ensure_config(config)
#     369     return cast(
#     370         "ChatGeneration",
# --> 371         self.generate_prompt(
#     372             [self._convert_input(input)],
#     373             stop=stop,
#     374             callbacks=config.get("callbacks"),
#     375             tags=config.get("tags"),
#     376             metadata=config.get("metadata"),
#     377             run_name=config.get("run_name"),
#     378             run_id=config.pop("run_id", None),
# ...
