# %%
from utils import *
from langchain_core.messages import HumanMessage, SystemMessage

# %%
# 메시지 정의
messages = [
    HumanMessage(content="무제한 요금제 알려줘")
]

# 시스템 메시지 정의
system_message = "당신은 통신 요금제 상담 어시스턴트입니다. 사용자 질문에 따라 적절한 정보를 제공합니다."

# 스마트비 호출
response = call_smartbee(
    messages=messages,
    system_message=system_message,
    tools=None,  # 툴 테스트는 나중에
    expect_json=False  # 우선 string 응답 받기
)

print("🧠 응답 결과:", response)
# Out:
# [call_llm_with_retries] Attempt 1:
# 🧠 응답 결과: content='무제한 요금제는 일반적으로 데이터, 통화, 문자 메시지를 무제한으로 사용할 수 있는 요금제를 말합니다. 각 통신사마다 제공하는 무제한 요금제의 세부 사항과 가격이 다를 수 있습니다. 일반적으로 다음과 같은 요소를 고려할 수 있습니다:\n\n1. **데이터 무제한**: 데이터 사용량에 제한이 없지만, 일정 사용량을 초과하면 속도가 제한될 수 있습니다.\n\n2. **통화 및 문자 무제한**: 국내 통화와 문자 메시지를 무제한으로 사용할 수 있습니다.\n\n3. **부가 서비스**: 일부 요금제는 스트리밍 서비스, 국제 전화, 로밍 데이터 등의 추가 혜택을 포함할 수 있습니다.\n\n4. **가격**: 무제한 요금제는 일반적으로 다른 요금제보다 가격이 높을 수 있습니다.\n\n5. **약정 조건**: 약정 기간에 따라 할인 혜택이 제공될 수 있습니다.\n\n각 통신사의 웹사이트나 고객센터를 통해 최신 요금제 정보를 확인하고, 본인의 사용 패턴에 맞는 요금제를 선택하는 것이 좋습니다.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 249, 'prompt_tokens': 45, 'total_tokens': 294, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_ee1d74bde0', 'id': 'chatcmpl-BuAef0owrYTezTtjfMoAJRb1chbq0', 'finish_reason': 'stop', 'logprobs': None} id='run--7cf4e9c9-f70e-4c65-80e8-af476769be68-0' usage_metadata={'input_tokens': 45, 'output_tokens': 249, 'total_tokens': 294, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
response
